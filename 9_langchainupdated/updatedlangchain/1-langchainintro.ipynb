# %% [markdown]
# ### Langchain Version V1
#
# ### Agents

# %%
import langchain
langchain.__version__
# Out:
# '1.4.0'

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.tools import tool
from langgraph.prebuilt import create_react_agent

# 1. Decorate the function as a tool
@tool
def get_weather(city: str) -> str:
    """Get the weather for a city."""
    return f"The weather in {city} is sunny."

# 2. Pass `model` as a keyword argument
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",  # or "gemini-2.0-flash"
    temperature=0
)

# 3. Create the agent
agent = create_react_agent(
    model=llm,
    tools=[get_weather],
    prompt="You are a helpful assistant."
)

# 4. Invoke the agent
response = agent.invoke({"messages": [("user", "What's the weather in Tokyo?")]})
print(response["messages"][-1].content)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# C:\Users\rajna\AppData\Local\Temp\ipykernel_22032\4192983912.py:18: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent = create_react_agent(
# The weather in Tokyo is sunny.

# %%
# from langchain.agents import create_agent
# from langchain_google_genai import ChatGoogleGenerativeAI

# def get_weather(city:str)-> str:
#     """Get the weather for a city."""
#     return f"The weather in {city} is sunny."

# agent=create_agent(
#     model=ChatGoogleGenerativeAI("gemini-3.0-flash"),
#     tools=[get_weather],
#     system_prompt="You are a helpful assistant."
# )
# agent

# %%
### run the agent
response=agent.invoke({"messages":[{"role":"user","content":"What is the weather like in New York?"}]})

# %%
response["messages"]
# Out:
# [HumanMessage(content='What is the weather like in New York?', additional_kwargs={}, response_metadata={}, id='b2df9084-f9f4-44c9-9e7d-8e7b23089bb1'),
# ...

# %%
agent.invoke({"messages":"What is the weather in New Yourk"})
# Out:
# {'messages': [HumanMessage(content='What is the weather in New Yourk', additional_kwargs={}, response_metadata={}, id='f9b573bb-c7f6-45e4-b63d-53657422937b'),
# ...
